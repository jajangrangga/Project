# %% [markdown]
# ***Menunjukkan data yang sudah di peroleh mobil listrik dari tahun 1992-2024***

# %%
import pandas as pd

car = 'electrical_data.csv'
df = pd.read_csv(car)

df
# Out:
#         VIN (1-10)    County            City State  Postal Code  Model Year  \
# 0       WAUTPBFF4H      King         Seattle    WA      98126.0        2017
# 1       WAUUPBFF2J  Thurston         Olympia    WA      98502.0        2018
# 2       5YJSA1E22H  Thurston           Lacey    WA      98516.0        2017
# 3       1C4JJXP62M  Thurston          Tenino    WA      98589.0        2021
# 4       5YJ3E1EC9L    Yakima          Yakima    WA      98902.0        2020
# ...            ...       ...             ...   ...          ...         ...
# 181453  50EA1TEA7P   Douglas  East Wenatchee    WA      98802.0        2023
# 181454  1C4JJXP60N   Spokane  Spokane Valley    WA      99206.0        2022
# 181455  5YJ3E1EA0M      King        Enumclaw    WA      98022.0        2021
# 181456  5YJ3E1EC8L     Clark       Vancouver    WA      98682.0        2020
# 181457  5YJSA1E27F   Whatcom      Bellingham    WA      98225.0        2015
#
# ...

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                         int64
# Base MSRP                                              int64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 398
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       3
# ...

# %%
 df.tail(10)
# Out:
#         VIN (1-10)    County            City State  Postal Code  Model Year  \
# 181448  KNDPZDAH7P   Whatcom        Ferndale    WA      98248.0        2023
# 181449  1N4BZ0CP6G  Franklin           Pasco    WA      99301.0        2016
# 181450  JTDKN3DPXD    Island       Greenbank    WA      98253.0        2013
# 181451  KM8KRDAF3P    Pierce          Tacoma    WA      98407.0        2023
# 181452  KNDPZDAH5P   Whatcom        Ferndale    WA      98248.0        2023
# 181453  50EA1TEA7P   Douglas  East Wenatchee    WA      98802.0        2023
# 181454  1C4JJXP60N   Spokane  Spokane Valley    WA      99206.0        2022
# 181455  5YJ3E1EA0M      King        Enumclaw    WA      98022.0        2021
# 181456  5YJ3E1EC8L     Clark       Vancouver    WA      98682.0        2020
# 181457  5YJSA1E27F   Whatcom      Bellingham    WA      98225.0        2015
#
#            Make          Model                   Electric Vehicle Type  \
# ...

# %%
# menghapus kolom index karena tidak di gunakan 
df.drop(columns=['Base MSRP'], inplace=True)

# %%
df.head(20)
# Out:
#     VIN (1-10)     County               City State  Postal Code  Model Year  \
# 0   WAUTPBFF4H       King            Seattle    WA      98126.0        2017
# 1   WAUUPBFF2J   Thurston            Olympia    WA      98502.0        2018
# 2   5YJSA1E22H   Thurston              Lacey    WA      98516.0        2017
# 3   1C4JJXP62M   Thurston             Tenino    WA      98589.0        2021
# 4   5YJ3E1EC9L     Yakima             Yakima    WA      98902.0        2020
# 5   1C4JJXP66P   Thurston            Olympia    WA      98501.0        2023
# 6   1G1RA6S53H     Kitsap            Keyport    WA      98345.0        2017
# 7   5YJ3E1EB5L  Snohomish  Mountlake Terrace    WA      98043.0        2020
# 8   WA1F2AFY1N       King            Seattle    WA      98119.0        2022
# 9   1G1RB6S59H   Thurston            Olympia    WA      98501.0        2017
# 10  1G1FW6S03J  Snohomish            Bothell    WA      98021.0        2018
# ...

# %%
df2 = df.query("County == 'Thurston'")
df2.head(20)
# Out:
#      VIN (1-10)    County      City State  Postal Code  Model Year  \
# 1    WAUUPBFF2J  Thurston   Olympia    WA      98502.0        2018
# 2    5YJSA1E22H  Thurston     Lacey    WA      98516.0        2017
# 3    1C4JJXP62M  Thurston    Tenino    WA      98589.0        2021
# 5    1C4JJXP66P  Thurston   Olympia    WA      98501.0        2023
# 9    1G1RB6S59H  Thurston   Olympia    WA      98501.0        2017
# 17   YV4BR0DL5N  Thurston   Olympia    WA      98512.0        2022
# 18   5YJ3E1EA1P  Thurston   Olympia    WA      98506.0        2023
# 19   3C3CFFGE8F  Thurston   Olympia    WA      98506.0        2015
# 38   5YJ3E1EB2L  Thurston   Olympia    WA      98502.0        2020
# 41   1N4AZ1CP7J  Thurston   Olympia    WA      98501.0        2018
# 42   1N4BZ1CP6K  Thurston   Olympia    WA      98516.0        2019
# 54   5YJXCDE24J  Thurston   Olympia    WA      98502.0        2018
# 96   JTDKARFP0H  Thurston   Olympia    WA      98502.0        2017
# ...

# %%
df2.shape
# Out:
# (6600, 16)

# %%
df2.to_csv('electrical_data.csv', index = False)
df2 = pd.read_csv ('electrical_data.csv')
df2
# Out:
#       VIN (1-10)    County     City State  Postal Code  Model Year       Make  \
# 0     WAUUPBFF2J  Thurston  Olympia    WA      98502.0        2018       AUDI
# 1     5YJSA1E22H  Thurston    Lacey    WA      98516.0        2017      TESLA
# 2     1C4JJXP62M  Thurston   Tenino    WA      98589.0        2021       JEEP
# 3     1C4JJXP66P  Thurston  Olympia    WA      98501.0        2023       JEEP
# 4     1G1RB6S59H  Thurston  Olympia    WA      98501.0        2017  CHEVROLET
# ...          ...       ...      ...   ...          ...         ...        ...
# 6595  3MW5P9J00M  Thurston  Olympia    WA      98502.0        2021        BMW
# 6596  7SAYGAEE7P  Thurston  Olympia    WA      98506.0        2023      TESLA
# 6597  KNDCE3LG7L  Thurston  Olympia    WA      98506.0        2020        KIA
# 6598  7SAYGDEEXR  Thurston  Olympia    WA      98506.0        2024      TESLA
# 6599  JTDKARFP0J  Thurston    Lacey    WA      98503.0        2018     TOYOTA
#
# ...
